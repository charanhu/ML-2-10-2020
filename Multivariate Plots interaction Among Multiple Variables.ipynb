# %% [markdown]
# Multivariate Plots:Interaction Among Multiple Variables
# Another type of visualization is multi-variable or “multivariate” visualization. With the help
# of multivariate visualization, we can understand interaction between multiple attributes of
# our dataset. The following are some techniques in Python to implement multivariate
# visualization:
# Correlation Matrix Plot
# Correlation is an indication about the changes between two variables. In our previous
# chapters, we have discussed Pearson’s Correlation coefficients and the importance of
# Correlation too. We can plot correlation matrix to show which variable is having a high or
# low correlation in respect to another variable.
# Example
# In the following example, Python script will generate and plot correlation matrix for the
# Pima Indian Diabetes dataset. It can be generated with the help of corr() function on Pandas
# DataFrame and plotted with the help of pyplot.

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,2)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,3)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(2,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(100)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1431906ec5ad> in <module>
#       7 correlations = data.corr()
#       8 fig = pyplot.figure()
# ----> 9 ax = fig.add_subplot(100)
#      10 cax = ax.matshow(correlations, vmin=-1, vmax=1)
#      11 fig.colorbar(cax)
#
# C:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      55                 raise ValueError(f'Number of rows must be > 0, not {rows}')
#      56             if cols <= 0:
# ...

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(121)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(101)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-f16eb3b1a378> in <module>
#       7 correlations = data.corr()
#       8 fig = pyplot.figure()
# ----> 9 ax = fig.add_subplot(101)
#      10 cax = ax.matshow(correlations, vmin=-1, vmax=1)
#      11 fig.colorbar(cax)
#
# C:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      55                 raise ValueError(f'Number of rows must be > 0, not {rows}')
#      56             if cols <= 0:
# ...

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(11)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c3884d9681cc> in <module>
#       7 correlations = data.corr()
#       8 fig = pyplot.figure()
# ----> 9 ax = fig.add_subplot(11)
#      10 cax = ax.matshow(correlations, vmin=-1, vmax=1)
#      11 fig.colorbar(cax)
#
# C:\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1378         if len(args) == 1 and isinstance(args[0], Integral):
#    1379             if not 100 <= args[0] <= 999:
# -> 1380                 raise ValueError("Integer subplot specification must be a "
#    1381                                  "three-digit number, not {}".format(args[0]))
#    1382             args = tuple(map(int, str(args[0])))
#
# ValueError: Integer subplot specification must be a three-digit number, not 11

# %%
from matplotlib import pyplot
from pandas import read_csv
import numpy
Path = r"pima-indians-diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(Path, names=names)
correlations = data.corr()
fig = pyplot.figure()
ax = fig.add_subplot(131)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %% [markdown]
# From the above output of correlation matrix, we can see that it is symmetrical i.e. the
# bottom left is same as the top right. It is also observed that each variable is positively
# correlated with each other.
